# %%
import serial
import time

end_time = time.time() + 5

samples = []
ser = serial.Serial('COM7')
print(ser.name)

while time.time() < end_time:
    x = ser.read(11)
    samples.append(x)

print(len(samples))
print(samples)
ser.close()
# Out:
# COM7
# 11949
# [b'ffffffff3b2', b'31e1515\r\nff', b'ffffff49211', b'81919\r\nffff', b'ffff4b28151', b'a1a\r\nffffff', b'ff4a2618151', b'5\r\nffffffff', b'4b22191212\r', b'\nffffffff40', b'1d181212\r\nf', b'fffffff3e21', b'141414\r\nfff', b'fffff311812', b'1212\r\nfffff', b'fff221613c\r', b'\nffffffff1c', b'10b\r\nffffff', b'ff1711a\r\nff', b'ffffffa\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff3\r\nff', b'ffffff2\r\nff', b'ffffff6\r\nff', b'ffffff3\r\nff', b'ffffff5\r\nff', b'ffffffc\r\nff', b'ffffffe\r\nff', b'ffffff10b\r\n', b'ffffffff10a', b'\r\nffffffff1', b'5a\r\nfffffff', b'f15a\r\nfffff', b'fff14a\r\nfff', b'fffff1f1913', b'1717\r\nfffff', b'fff4621161a', b'1a\r\nfffffff', b'f4b27171818', b'\r\nffffffff4', b'd201b1717\r\n', b'ffffffff4c2', b'01a1a1a\r\nff', b'ffffff431e1', b'9e\r\nfffffff', b'f4323141515', b'\r\nffffffff3', b'c171af\r\nfff', b'fffff291314', b'e\r\nffffffff', b'221211a\r\nff', b'ffffff1c11b', b'\r\nffffffff1', b'6e\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f0\r\nfffffff', b'f2\r\nfffffff', b'f4\r\nfffffff', b'f3\r\nfffffff', b'f5\r\nfffffff', b'fa\r\nfffffff', b'fa\r\nfffffff', b'fd\r\nfffffff', b'f118\r\nfffff', b'fff15b\r\nfff', b'fffff14a\r\nf', b'fffffff15d\r', b'\nffffffff15', b'c\r\nffffffff', b'331a171717\r', b'\nffffffff46', b'26181414\r\nf', b'fffffff4d22', b'1c1616\r\nfff', b'fffff4d231b', b'1717\r\nfffff', b'fff4a241717', b'17\r\nfffffff', b'f3e22161717', b'\r\nffffffff3', b'e1b19e\r\nfff', b'fffff361b15', b'd\r\nffffffff', b'2618a\r\nffff', b'ffff1e10d\r\n', b'ffffffff1b1', b'0d\r\nfffffff', b'f13e\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff0\r\nfffff', b'fff1\r\nfffff', b'fff1\r\nfffff', b'fff4\r\nfffff', b'fff5\r\nfffff', b'fff6\r\nfffff', b'fffb\r\nfffff', b'fffb\r\nfffff', b'fffe\r\nfffff', b'fff10a\r\nfff', b'fffff15a\r\nf', b'fffffff14b\r', b'\nffffffff12', b'e\r\nffffffff', b'1710c\r\nffff', b'ffff3e26171', b'717\r\nffffff', b'ff47231c111', b'1\r\nffffffff', b'4f231d1212\r', b'\nffffffff49', b'221b1919\r\nf', b'fffffff4a22', b'181111\r\nfff', b'fffff3e2416', b'1414\r\nfffff', b'fff3d191715', b'15\r\nfffffff', b'f3014151010', b'\r\nffffffff2', b'71212f\r\nfff', b'fffff1a11b\r', b'\nffffffff14', b'e\r\nffffffff', b'8\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'0\r\nffffffff', b'2\r\nffffffff', b'0\r\nffffffff', b'2\r\nffffffff', b'7\r\nffffffff', b'5\r\nffffffff', b'5\r\nffffffff', b'b\r\nffffffff', b'f\r\nffffffff', b'd\r\nffffffff', b'12d\r\nffffff', b'ff14a\r\nffff', b'ffff15b\r\nff', b'ffffff14b\r\n', b'ffffffff221', b'5131919\r\nff', b'ffffff441e1', b'e1818\r\nffff', b'ffff49221a1', b'717\r\nffffff', b'ff4b2815131', b'3\r\nffffffff', b'4a271b1515\r', b'\nffffffff40', b'20141616\r\nf', b'fffffff4222', b'141313\r\nfff', b'fffff3d171a', b'1010\r\nfffff', b'fff2b14d\r\nf', b'fffffff2216', b'108\r\nffffff', b'ff1dd\r\nffff', b'ffff16f\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff0\r\nff', b'ffffff2\r\nff ...

# %%
ser.close()
ser = serial.Serial('COM7')
ser.close()

# %%
ser.close()
ser = serial.Serial('COM5')
ser.close()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-37-e32e1ed4493f> in <module>()
#       1 ser.close()
# ----> 2 ser = serial.Serial('COM5')
#       3 ser.close()
#
# ~\Anaconda3\envs\senoir-project\lib\site-packages\serial\serialwin32.py in __init__(self, *args, **kwargs)
#      29         self._overlapped_read = None
#      30         self._overlapped_write = None
# ---> 31         super(Serial, self).__init__(*args, **kwargs)
#      32
#      33     def open(self):
#
# ~\Anaconda3\envs\senoir-project\lib\site-packages\serial\serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     238
#     239         if port is not None:
# --> 240             self.open()
#     241
#     242     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# ~\Anaconda3\envs\senoir-project\lib\site-packages\serial\serialwin32.py in open(self)
#      60         if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      61             self._port_handle = None    # 'cause __del__ is called anyway
# ---> 62             raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      63
#      64         try:
#
# SerialException: could not open port 'COM5': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)
